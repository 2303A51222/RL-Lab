# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51222/RL-Lab/blob/main/RL_Ass_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# RANDOM AGENT FOR CLIFFWALKING AND TAXI
# ============================================================

# !pip install -q -U gymnasium

import gymnasium as gym


def random_agent(environment_name, number_of_episodes=5):

    env = gym.make(environment_name)

    print("\n" + "=" * 60)
    print("Environment:", environment_name)
    print("=" * 60)

    for episode in range(1, number_of_episodes + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        # State -> Action -> Reward -> Next State
        while not (terminated or truncated):

            # Select random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Update total reward
            total_reward += reward
            steps += 1

            # Move to next state
            state = next_state

        # Calculate average reward
        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Number of Steps:", steps)
        print("Average Reward:", round(average_reward, 2))
        print("-" * 60)

    env.close()


# ============================================================
# CLIFFWALKING
# ============================================================

random_agent("CliffWalking-v1", 5)


# ============================================================
# TAXI
# ============================================================

random_agent("Taxi-v4", 5)
# Out:
# ...
# Environment: CliffWalking-v1
# ...
# Episode: 1
# Total Reward: -124991
# Number of Steps: 12626
# Average Reward: -9.9
# ------------------------------------------------------------
# Episode: 2
# Total Reward: -61369
# Number of Steps: 6028
# Average Reward: -10.18
# ------------------------------------------------------------
# Episode: 3
# Total Reward: -115504
# Number of Steps: 11257
# Average Reward: -10.26
# ------------------------------------------------------------
# Episode: 4
# Total Reward: -74084
# Number of Steps: 7457
# Average Reward: -9.93
# ------------------------------------------------------------
# Episode: 5
# Total Reward: -17980
# Number of Steps: 1942
# Average Reward: -9.26
# ------------------------------------------------------------
#
# ...
# Environment: Taxi-v4
# ...
# Episode: 1
# Total Reward: -758
# Number of Steps: 200
# Average Reward: -3.79
# ------------------------------------------------------------
# Episode: 2
# Total Reward: -893
# Number of Steps: 200
# ...
